# %%
# !pip install tweepy
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %%
consumer_key = "4Brt2PIORHufxQVZ2OVbHoox2"

# %%
consumer_secret = "fFrt1587ZmvA74mpRary1rgL8B5TmP832GaOSuWjDquENkIgnZ"

# %%
access_token = "230518674-Supaf028LmmYFlBzOO8bIRGCDxqk7sDULZfOTwzV"

# %%
access_token_secret = "uhJIvEQnIPq57UEdGvKDRfPjf1d5GOBSLqIGhJBu4tXdd"

# %%
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# criando uma classe para capturar os streams de dados do Twitter e 
# armazenar no mongoDB
class MyListener(StreamListener):
    
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at": created_at, "id_str":id_str, "text":text}
        tweetind = col.insert_one(obj).inserted_id
        
        print(obj)
        return True

# %%
myListener = MyListener()

# %%
myStream = Stream(auth, listener = myListener)

# %%
# preparando a conexao com o MongoDB
from pymongo import MongoClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-3bd266a36cb2> in <module>()
#       1 # preparando a conexao com o MongoDB
# ----> 2 from pymongo import MongoClient
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
# !pip install pymongo
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# preparando a conexao com o MongoDB
from pymongo import MongoClient

# %%
#conexão ao mongodb
client = MongoClient('localhost', 27017)

# %%
#criando o banco de dados twitterdb
db = client.twitterdb

# %%
# criando a collection "col"
col = db.tweets

# %%
# crinado lista com as palavras chave para buscar nos tweets
keywords = [ 'Data Science', 'Python' ]

# %%
# iniciando o filtro e gravando os tweets no mongodb
myStream.filter(track=keywords)
# Out:
# {'created_at': 'Tue Oct 08 16:17:53 +0000 2019', 'id_str': '1181604636840644608', 'text': 'RT @Antonia_R: Explore your data in virtual reality at #ADASS2019 Go to the  @ESAesdc ESAC science data centre booth! https://t.co/dIhhYWLn…', '_id': ObjectId('5d9cb6b5f56cc05272670a68')}
# {'created_at': 'Tue Oct 08 16:17:57 +0000 2019', 'id_str': '1181604654402002944', 'text': 'AgWeatherNet is thrilled to welcome Lana Cohen to our team as the new Weather Data Scientist. With a PhD in Atmosph… https://t.co/9Ih6qfMrsA', '_id': ObjectId('5d9cb6b9f56cc05272670a69')}
# {'created_at': 'Tue Oct 08 16:18:00 +0000 2019', 'id_str': '1181604667333197828', 'text': "RT @MedicalQuack: Problem: Data Science Has Become About Lending False Credibility To Decisions We've Already Made https://t.co/ukz5xwBQia…", '_id': ObjectId('5d9cb6bcf56cc05272670a6a')}
# ...

# %%
myStream.disconnect()

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5d9cb6b5f56cc05272670a68'),
#  'created_at': 'Tue Oct 08 16:17:53 +0000 2019',
#  'id_str': '1181604636840644608',
#  'text': 'RT @Antonia_R: Explore your data in virtual reality at #ADASS2019 Go to the  @ESAesdc ESAC science data centre booth! https://t.co/dIhhYWLn…'}

# %%
# criando dataset com dados retornados do mongodb
dataset = [ {"created_at": item["created_at"], "text": item["text"]} for item in col.find()]

# %%
# importando modulo pandas p/ trabalhar com datasets em python
import pandas as pd

# %%
# criando um dataframe a partir do dataset
df = pd.DataFrame(dataset)

# %%
#imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Tue Oct 08 16:17:53 +0000 2019
# 1   Tue Oct 08 16:17:57 +0000 2019
# 2   Tue Oct 08 16:18:00 +0000 2019
# 3   Tue Oct 08 16:18:00 +0000 2019
# 4   Tue Oct 08 16:18:02 +0000 2019
# 5   Tue Oct 08 16:18:03 +0000 2019
# 6   Tue Oct 08 16:18:06 +0000 2019
# 7   Tue Oct 08 16:18:06 +0000 2019
# 8   Tue Oct 08 16:18:07 +0000 2019
# 9   Tue Oct 08 16:18:09 +0000 2019
# 10  Tue Oct 08 16:18:11 +0000 2019
# 11  Tue Oct 08 16:18:11 +0000 2019
# 12  Tue Oct 08 16:18:13 +0000 2019
# 13  Tue Oct 08 16:18:15 +0000 2019
# 14  Tue Oct 08 16:18:17 +0000 2019
# 15  Tue Oct 08 16:18:19 +0000 2019
# 16  Tue Oct 08 16:18:19 +0000 2019
# 17  Tue Oct 08 16:18:21 +0000 2019
# 18  Tue Oct 08 16:18:22 +0000 2019
# 19  Tue Oct 08 16:18:22 +0000 2019
# 20  Tue Oct 08 16:18:23 +0000 2019
# 21  Tue Oct 08 16:18:26 +0000 2019
# 22  Tue Oct 08 16:18:27 +0000 2019
# 23  Tue Oct 08 16:18:39 +0000 2019
# 24  Tue Oct 08 16:18:39 +0000 2019
# ...

# %%
# analise de dados com pandas e Scikit-Learn
#importando o modulo Scikit Learn

from sklearn.feature_extraction.text import CountVectorizer

# %%
#usando o metodo CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# contando o numero de ocorrencias das principais palavras em nosso dataset do twitter
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:100]
# Out:
#               word  count
# 0               rt     20
# 1            https     18
# 2               co     18
# 3              the     13
# 4             data     12
# 5           python     11
# 6          science      8
# 7               to      7
# 8         learning      6
# 9               in      6
# 10              on      5
# 11             for      5
# 12              la      5
# 13              of      5
# 14           monty      4
# 15     datascience      4
# 16            with      4
# 17             and      4
# 18             you      3
# 19              ai      3
# 20              de      3
# 21              is      3
# 22       analytics      3
# 23             our      3
# 24     cathcervoni      2
# 25     christopher      2
# 26             géo      2
# 27              by      2
# 28           nudge      2
# 29         nothing      2
# ..             ...    ...
# 70            peop      1
# 71     machinelear      1
# 72             put      1
# ...
