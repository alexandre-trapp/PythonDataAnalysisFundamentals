# %%
import pandas as pd

# %%
file_name = "arquivos/binary.csv"
df = pd.read_csv(file_name)
df.head()
# Out:
#    index  admit  gre   gpa  rank
# 0    NaN      0  380  3.61     3
# 1    1.0      1  660  3.67     3
# 2    2.0      1  880  4.00     1
# 3    3.0      1  640  3.19     4
# 4    4.0      0  520  2.93     4

# %%
file2 = "arquivos/salarios.csv"
df2 = pd.read_csv(file2)
df2.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1       AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4   ABARCA,  FRANCES J                          POLICE OFFICER
#
#                     Department Full or Part-Time Salary or Hourly  \
# 0                       POLICE                 F           Salary
# 1                       POLICE                 F           Salary
# 2  FLEET & FACILITY MANAGEMENT                 F           Salary
# 3                  WATER MGMNT                 F           Salary
# 4                       POLICE                 F           Salary
#
#    Typical Hours Annual Salary  Hourly Rate
# 0            NaN    101,442.00          NaN
# 1            NaN     94,122.00          NaN
# 2            NaN    111,024.00          NaN
# 3            NaN    114,780.00          NaN
# 4            NaN     48,078.00          NaN
